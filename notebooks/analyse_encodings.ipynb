# %%
from medbert.common import common
from os.path import join
import importlib
importlib.reload(common)
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
pat_ids, pat_vec = common.get_encodings_from_npz(join("..","models","mlm_plos_pretrained","test","encodings","encodings.npz"))

# %%
pat_vec2 = PCA(n_components=2).fit_transform(pat_vec)
plt.scatter(pat_vec2[:,0], pat_vec2[:,1])
